# %% [markdown]
# # 시각화

# %% [markdown]
# * matplotlib과 pandas을 이용한 시각화
# * 240502

# %% [markdown]
# 자료의 종류
# * 수치형 : 양적자료. 이산 / 연속
# * 범주형 : 질적자료. 순위 / 명목

# %% [markdown]
# # matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.font_manager
fpaths = matplotlib.font_manager.findSystemFonts()
for i in fpaths:
    f = matplotlib.font_manager.get_font(i)
    print(f.family_name)
# Out:
# Constantia
# Tahoma
# NanumGothic
# Calisto MT
# Webdings
# Ami R
# OCR A Extended
# Century Gothic
# Rockwell Condensed
# Bodoni MT
# Avenir Next Cyr W04 Regular
# HYGungSo-Bold
# Harrington
# Eras Medium ITC
# Arial
# NanumSquare
# Bradley Hand ITC
# Cumberland AMT
# Nirmala UI
# Arial
# Palatino Linotype
# Lucida Sans
# Malgun Gothic
# HYMyeongJo-Extra
# Times New Roman Symbol
# Perpetua
# Ebrima
# Berlin Sans FB Demi
# MSugiHeulim
# NanumGothic
# Algerian
# Algerian
# Calibri
# MoeumT R
# New Gulim
# Microsoft PhagsPa
# Segoe MDL2 Assets
# Batang
# Perpetua Titling MT
# HYShortSamul-Medium
# Consolas
# NanumBarunGothic
# Eras Light ITC
# Perpetua
# Times New Roman Symbol
# Gulim
# Avenir Next LT W04 Regular
# Felix Titling
# HYPost-Medium
# Gulim
# HYGraphic-Medium
# Freestyle Script
# Californian FB
# Californian FB
# Avenir Next LT W04
# Century
# Segoe UI
# Gill Sans MT
# High Tower Text
# SAS Monospace
# MHunmin
# Baskerville Old Face
# HYPost-Medium
# Candara
# HoloLens MDL2 Assets
# Constantia
# Javanese Text
# Trebuchet MS
# Segoe Script
# Tw Cen MT Condensed
# Lucida Fax
# Curlz MT
# NanumBarunpen
# Segoe UI Emoji
# Times New Roman
# Lucida Bright
# Magic R
# Microsoft Sans Serif
# Gill Sans MT Ext Condensed Bold
# Myanmar Text
# KBIZmjo B
# Pristina
# Corbel
# Webdings
# Ink Free
# Franklin Gothic Demi
# Gill Sans MT Condensed
# Segoe UI
# Microsoft Yi Baiti
# Calibri
# Malgun Gothic
# Verdana
# Franklin Gothic Demi
# MJemokBatang
# Segoe Print
# HyhwpEQ
# Engravers MT
# KBIZmjo M
# Tahoma
# Microsoft YaHei
# HYSinMyeongJo-Medium
# Thorndale AMT
# Palatino Linotype
# Poor Richard
# Script MT Bold
# SAS Monospace Bold
# SimSun-ExtB
# Trebuchet MS
# Vivaldi
# MS Outlook
# Gill Sans Ultra Bold Condensed
# Verdana
# Gill Sans MT Ext Condensed Bold
# Rockwell Extra Bold
# Arial Unicode MS
# Rockwell
# SimSun
# Corbel
# Yu Gothic
# MSugiJeong
# NanumMyeongjo
# Papyrus
# Old English Text MT
# Eras Bold ITC
# HYGothic-Medium
# Bodoni MT
# Mistral
# Ebrima
# Segoe UI
# Eras Medium ITC
# Bahnschrift
# Bookman Old Style
# Ebrima
# HYGungSo-Bold
# Albany AMT
# MYingHei_18030_C-Medium
# NanumSquare
# Cumberland AMT
# Arial
# High Tower Text
# Bookman Old Style
# Berlin Sans FB
# Microsoft New Tai Lue
# Niagara Engraved
# Perpetua Titling MT
# Gill Sans Ultra Bold
# Arial
# Rockwell
# Palatino Linotype
# Lucida Bright
# Times New Roman Uni
# Avenir Next LT W04
# CSongGB18030C-LightHWL
# NanumBarunGothic
# Ravie
# Century Schoolbook
# Lucida Bright
# HYGothic-Extra
# Tempus Sans ITC
# Magneto
# Courier New
# Niagara Solid
# Franklin Gothic Heavy
# NanumSquare
# Modern No. 20
# Constantia
# Bodoni MT
# Calibri
# Lucida Sans Typewriter
# Georgia
# Playbill
# Bradley Hand ITC
# French Script MT
# Kristen ITC
# Bodoni MT
# Franklin Gothic Book
# HeiT
# KBIZgo M
# Arial
# Constantia
# Lucida Sans
# Segoe UI Historic
# Nirmala UI
# Pristina
# Consolas
# Tw Cen MT
# HYHeadLine-Medium
# Juice ITC
# Avenir Next Cyr W04
# Castellar
# NanumGothic
# NanumSquare
# Franklin Gothic Medium
# Corbel
# Consolas
# Franklin Gothic Demi
# Corbel
# Leelawadee
# Segoe Script
# KBIZmjo R
# Segoe UI
# Bodoni MT
# Segoe UI
# HCR Batang Ext
# Microsoft Sans Serif
# Wingdings
# Bookman Old Style
# Informal Roman
# Lucida Fax
# Gigi
# NanumMyeongjo
# Goudy Stout
# Gill Sans MT
# Times New Roman
# Bodoni MT
# Arial
# Californian FB
# Segoe UI Emoji
# Leelawadee
# Times New Roman
# Rockwell
# Bell MT
# KBIZmjo M
# Thorndale AMT
# Tw Cen MT Condensed
# Arial Symbol
# Rage Italic
# Goudy Stout
# Tw Cen MT
# NanumGothic
# Lucida Bright
# Arial
# Cooper Black
# Courier New
# Cambria
# Microsoft Himalaya
# Tw Cen MT
# Albany AMT
# Lucida Sans
# MS Gothic
# Gill Sans MT
# Wingdings 3
# Lucida Sans Typewriter
# HYGothic-Medium
# Avenir Next Cyr W04 Italic
# Rockwell Extra Bold
# Segoe Script
# MYingHei_18030_C-MediumHWL
# Century Schoolbook
# Juice ITC
# Stencil
# Times New Roman Symbol
# Impact
# Niagara Engraved
# Cumberland AMT
# Haettenschweiler
# Albany AMT
# Yu Gothic
# Onyx
# Gabriola
# Lucida Sans Typewriter
# NanumSquare
# HCR Dotum
# Comic Sans MS
# Calibri
# Palatino Linotype
# Gill Sans MT
# Rockwell
# Georgia
# Freestyle Script
# Century Gothic
# Goudy Old Style
# Segoe UI
# Times New Roman
# Tw Cen MT
# Stencil
# Forte
# Copperplate Gothic Bold
# NanumMyeongjo
# Ravie
# Bodoni MT
# Bell MT
# Georgia
# HYPost-Light
# Thorndale AMT
# Bodoni MT
# Segoe UI
# Yu Gothic
# Cumberland AMT
# Century Schoolbook
# Gill Sans MT Condensed
# Avenir Next LT W04 Light Italic
# Microsoft Uighur
# Monotype Corsiva
# Rockwell Condensed
# Thorndale AMT
# Trebuchet MS
# Maiandra GD
# Snap ITC
# Arial Rounded MT Bold
# HYPost-Light
# Garamond
# Consolas
# Georgia
# Eras Demi ITC
# Brush Script MT
# Mongolian Baiti
# Microsoft New Tai Lue
# MS Reference Sans Serif
# Wingdings 3
# Curlz MT
# Lucida Sans
# Ami R
# Segoe UI Symbol
# NewJumja
# Mistral
# NanumBarunGothic
# Wide Latin
# NanumBarunGothic
# Arial Symbol
# Arial
# Cambria
# Microsoft New Tai Lue
# Franklin Gothic Medium
# Book Antiqua
# Book Antiqua
# Californian FB
# HCR Dotum
# Microsoft Uighur
# Arial Symbol
# Nirmala UI
# Bookman Old Style
# Candara
# Trebuchet MS
# Candara
# MHunmin
# Viner Hand ITC
# Javanese Text
# Bell MT
# OCR A Extended
# Gloucester MT Extra Condensed
# Arial
# Calisto MT
# Franklin Gothic Medium
# Perpetua
# Trebuchet MS
# Cambria
# Copperplate Gothic Light
# KBIZgo B
# Lucida Bright
# Lucida Sans Typewriter
# Bodoni MT
# HCR Batang ExtB
# Microsoft Yi Baiti
# Perpetua
# Segoe UI
# NanumBarunGothic
# Times New Roman
# Magneto
# Candara
# Palatino Linotype
# Monotype Corsiva
# Comic Sans MS
# NanumMyeongjo
# Corbel
# Microsoft Uighur
# Franklin Gothic Heavy
# Pyunji R
# Franklin Gothic Medium
# Book Antiqua
# Garamond
# Cambria
# Gloucester MT Extra Condensed
# Arial Symbol
# NanumBarunGothic
# Segoe MDL2 Assets
# Perpetua Titling MT
# Candara
# Microsoft YaHei
# Goudy Old Style
# Constantia
# Century Gothic
# Arial Symbol
# Lucida Sans
# Agency FB
# Microsoft PhagsPa
# Candara
# Colonna MT
# Tw Cen MT
# Vivaldi
# KBIZgo R
# Lucida Sans Typewriter
# Segoe UI Symbol
# Perpetua Titling MT
# Lucida Sans Typewriter
# HYGraphic-Medium
# Candara
# Bernard MT Condensed
# Segoe UI
# Calisto MT
# Garamond
# Century Schoolbook
# Microsoft JhengHei
# Footlight MT Light
# MGungJeong
# Microsoft JhengHei
# Wide Latin
# High Tower Text
# Imprint MT Shadow
# Lucida Console
# CSongGB18030C-Light
# Lucida Sans
# MDotum
# NewJumja
# Blackadder ITC
# Lucida Sans Typewriter
# Cumberland AMT
# Avenir Next Cyr W04
# Batang
# Rage Italic
# Nanum Brush Script
# Gadugi
# Rockwell
# Broadway
# Tahoma
# Avenir Next LT W04 Italic
# Sitka Small
# Yet R
# HyhwpEQ
# Imprint MT Shadow
# Franklin Gothic Book
# Century Gothic
# NanumBarunGothic
# HCR Batang ExtB
# Avenir Next LT W04 Light Italic
# HCR Dotum
# Lucida Bright
# MS Outlook
# Times New Roman
# Leelawadee
# Leelawadee
# Arial
# HYHeadLine-Medium
# Leelawadee UI
# Myanmar Text
# Headline R
# Snap ITC
# Garamond
# Calibri
# MoeumT R
# Bodoni MT
# HCR Batang
# Century Schoolbook
# MYingHei_18030_C-MediumHWL
# Albany AMT
# Lucida Calligraphy
# Sitka Small
# Bodoni MT
# Gabriola
# Segoe UI
# Segoe UI
# Yu Gothic
# Corbel
# Bodoni MT
# Century Gothic
# Bodoni MT
# Franklin Gothic Heavy
# Avenir Next Cyr W04 Light
# Symbol MT
# Arial
# Parchment
# Perpetua
# HCR Batang
# HCR Batang
# Corbel
# Verdana
# Pyunji R
# Segoe UI
# Franklin Gothic Demi
# Malgun Gothic
# Footlight MT Light
# Thorndale AMT
# Albany AMT
# MDotum
# Times New Roman Symbol
# Britannic Bold
# Microsoft Uighur
# Informal Roman
# Bodoni MT
# Edwardian Script ITC
# Franklin Gothic Demi Cond
# Lucida Fax
# Microsoft PhagsPa
# Elephant
# Gadugi
# Segoe Print
# Gill Sans MT
# Consolas
# KBIZmjo B
# Cambria
# Blackadder ITC
# Marlett
# MSugiJeong
# SAS Monospace Bold
# Harlow Solid Italic
# Calibri
# Microsoft Tai Le
# Avenir Next LT W04 Light
# Corbel
# Gill Sans Ultra Bold
# Yet R
# MS Gothic
# Nanum Brush Script
# Cumberland AMT
# Palace Script MT
# Microsoft YaHei
# MSugiHeulim
# Courier New
# Gill Sans MT
# Cambria
# Avenir Next LT W04
# Trebuchet MS
# Palatino Linotype
# Verdana
# Bookshelf Symbol 7
# Tempus Sans ITC
# Lucida Console
# Lucida Handwriting
# Times New Roman Symbol
# Lucida Fax
# Microsoft JhengHei
# Elephant
# Franklin Gothic Book
# Colonna MT
# Avenir Next LT W04 Light
# NanumBarunGothic
# NanumSquare
# Century Schoolbook
# Segoe UI
# Avenir Next Cyr W04
# Lucida Fax
# Trebuchet MS
# Avenir Next LT W04 Regular
# Vladimir Script
# Perpetua
# Gadugi
# Cambria
# Eras Light ITC
# Goudy Old Style
# Agency FB
# Microsoft PhagsPa
# Cambria
# Times New Roman Uni
# Verdana
# MJemokGothic
# NanumMyeongjo
# MV Boli
# Segoe UI
# Georgia
# Sylfaen
# Palace Script MT
# Viner Hand ITC
# Thorndale AMT
# Berlin Sans FB
# NanumBarunpen
# CSongGB18030C-LightHWL
# Courier New
# Yu Gothic
# Franklin Gothic Book
# Rockwell
# Comic Sans MS
# Candara
# Microsoft Tai Le
# Chiller
# Century Schoolbook
# Ebrima
# Times New Roman
# Leelawadee UI
# Malgun Gothic
# Courier New
# HCR Batang ExtB
# Elephant
# Courier New
# Microsoft JhengHei
# Nirmala UI
# Segoe UI
# Bodoni MT
# MJemokBatang
# Bodoni MT
# Berlin Sans FB
# Playbill
# Script MT Bold
# Microsoft YaHei
# Book Antiqua
# MS Reference Sans Serif
# Candara
# Old English Text MT
# Arial
# Gill Sans Ultra Bold Condensed
# Bookshelf Symbol 7
# Gigi
# Georgia
# HCR Dotum
# Tw Cen MT
# HCR Batang
# HeiT
# HCR Dotum Ext
# Microsoft JhengHei
# Microsoft JhengHei
# Tw Cen MT
# Bahnschrift
# Candara
# Arial Rounded MT Bold
# Arial Unicode MS
# Segoe Script
# Showcard Gothic
# Consolas
# Albany AMT
# Segoe UI
# Berlin Sans FB
# Sitka Small
# Bodoni MT
# Myanmar Text
# NanumGothic
# Calibri
# MV Boli
# Franklin Gothic Heavy
# Franklin Gothic Medium Cond
# Chiller
# Courier New
# Mongolian Baiti
# NanumGothic
# MGungJeong
# Consolas
# High Tower Text
# Yu Gothic
# Bookman Old Style
# Ink Free
# Bell MT
# NanumSquare
# Sitka Small
# NanumMyeongjo
# Berlin Sans FB Demi
# Goudy Old Style
# MGungHeulim
# Bauhaus 93
# Corbel
# Georgia
# Leelawadee UI
# Niagara Solid
# French Script MT
# NanumSquare
# Avenir Next Cyr W04 Light
# SimSun
# Comic Sans MS
# Gill Sans MT
# Lucida Fax
# Century
# Avenir Next Cyr W04 Light It
# Calisto MT
# Perpetua
# Lucida Handwriting
# Monotype Sorts
# NanumGothic
# Arial
# Brush Script MT
# Sitka Small
# Bodoni MT
# Trebuchet MS
# Monotype Sorts
# Segoe UI
# Bauhaus 93
# Lucida Calligraphy
# Rockwell
# Segoe Print
# Avenir Next LT W04 Italic
# Broadway
# Microsoft Tai Le
# Comic Sans MS
# Book Antiqua
# Georgia
# Segoe UI
# Cumberland AMT
# Forte
# Calibri
# Eras Bold ITC
# Microsoft YaHei
# Franklin Gothic Demi Cond
# Bookman Old Style
# Arial
# Calibri
# Bell MT
# MingLiU-ExtB
# Matura MT Script Capitals
# Goudy Old Style
# Garamond
# Avenir Next Cyr W04
# Lucida Fax
# CSongGB18030C-Light
# Palatino Linotype
# HYGothic-Extra
# Segoe UI
# Haettenschweiler
# Jokerman
# Arial
# Baskerville Old Face
# Bookman Old Style
# Calibri
# Lucida Sans Typewriter
# Microsoft Himalaya
# Segoe UI
# Elephant
# Calibri
# Agency FB
# HCR Batang Ext
# Century Gothic
# Parchment
# Calisto MT
# Leelawadee UI
# Cumberland AMT
# Wingdings 2
# Tw Cen MT Condensed
# Corbel
# Headline R
# Arial Symbol
# HCR Batang ExtB
# Castellar
# Constantia
# Times New Roman Symbol
# Bodoni MT
# Segoe UI
# Segoe Print
# Britannic Bold
# Vladimir Script
# Segoe UI
# Arial
# MingLiU-ExtB
# Leelawadee UI
# Arial
# MT Extra
# NanumBarunpen
# Comic Sans MS
# Lucida Bright
# Candara
# Comic Sans MS
# HYMyeongJo-Extra
# HYSinMyeongJo-Medium
# New Gulim
# Verdana
# Corbel
# Bodoni MT
# Corbel
# Lucida Fax
# Nanum Pen Script
# Avenir Next Cyr W04 Italic
# Myanmar Text
# Tw Cen MT Condensed Extra Bold
# Malgun Gothic
# Engravers MT
# Verdana
# Showcard Gothic
# Lucida Bright
# Perpetua
# Californian FB
# Palatino Linotype
# Symbol
# Sitka Small
# Courier New
# Avenir Next Cyr W04 Light It
# HCR Dotum Ext
# Albany AMT
# MS Reference Specialty
# Centaur
# Thorndale AMT
# Bodoni MT
# Bernard MT Condensed
# Calisto MT
# NanumBarunpen
# Book Antiqua
# Copperplate Gothic Bold
# Constantia
# Constantia
# MJemokGothic
# NanumGothic
# KBIZgo R
# HYPMokGak-Bold
# Symbol
# Microsoft YaHei
# Sylfaen
# Sitka Small
# Copperplate Gothic Light
# Eras Demi ITC
# Harrington
# Avenir Next Cyr W04 Regular
# Kunstler Script
# Verdana
# Franklin Gothic Medium Cond
# Gill Sans MT
# Jokerman
# KBIZgo M
# Sitka Small
# Segoe UI
# HoloLens MDL2 Assets
# Gadugi
# Malgun Gothic
# Times New Roman
# Century Gothic
# Lucida Sans
# MBatang
# Onyx
# Segoe UI
# Bodoni MT
# Century Gothic
# Poor Richard
# Lucida Sans Unicode
# Segoe UI Historic
# Thorndale AMT
# Papyrus
# Modern No. 20
# Times New Roman Symbol
# Felix Titling
# KBIZmjo R
# Kunstler Script
# MBatang
# Microsoft Tai Le
# Tahoma
# Nirmala UI
# Times New Roman Symbol
# SAS Monospace
# Edwardian Script ITC
# Calisto MT
# SimSun-ExtB
# Candara
# Impact
# Tw Cen MT Condensed Extra Bold
# HYShortSamul-Medium
# HYPMokGak-Bold
# Comic Sans MS
# Albany AMT
# Tw Cen MT Condensed
# Rockwell Condensed
# Nanum Pen Script
# Lucida Sans
# Lucida Sans Unicode
# Calibri
# Tw Cen MT
# Californian FB
# Nirmala UI
# Harlow Solid Italic
# Symbol MT
# KBIZgo B
# MGungHeulim
# Bookman Old Style
# Book Antiqua
# Goudy Old Style
# Agency FB
# Magic R
# Yu Gothic
# Avenir Next LT W04
# Century Schoolbook
# Leelawadee UI
# MYingHei_18030_C-Medium
# Bell MT
# Arial Symbol
# Garamond
# Consolas
# Arial
# Microsoft New Tai Lue
# Wingdings 2
# Centaur
# Matura MT Script Capitals
# Cooper Black
# Kristen ITC
# Wingdings
# Calisto MT
# Yu Gothic
# Rockwell
# Rockwell Condensed
# Maiandra GD
# Book Antiqua
# MS Reference Specialty
# Arial Symbol

# %%
# 맑은 고딕체로 폰트 변경 방법
matplotlib.rcParams['font.family'] = 'MalgunGothic' 
matplotlib.rcParams['axes.unicode_minus'] = False

# import matplotlib
matplotlib.rcParams['font.family'] = 'gulim'
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = 'batang'
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = 'NanumGothic'
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = 'NanumMyeongjo'
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = 'HYGothic-Extra'
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 파이 그래프
# * 범주형 자료를 요약하는 방법
# * 부채꼴 = 비율
# * 비율 비교 시 이용

# %%
fruit=['사과','바나나','딸기','오렌지','포도']
fruit=['apple','banana','strawberry','orange','grape']
result=[7,6,3,2,2]
plt.pie(result)
plt.show()

#그래프 너비&높이 조절
plt.figure(figsize=(5,5))
plt.pie(result)
plt.show()

# %% [markdown]
# ## 파이 그래프의 특징
# * `plt.figure()`를 사용해서 조정

# %%
plt.figure(figsize=(5,5)) 
plt.pie(result, labels = fruit, autopct='%.0f') #비율값이 정수만 표시
plt.show() 

plt.figure(figsize=(5,5)) 
plt.pie(result, labels = fruit, autopct='%.1f') #비율값이 소수점 첫째 자리까지 표시
plt.show() 

plt.figure(figsize=(5,5)) 
plt.pie(result, labels = fruit, autopct='%.0f%%') #비율값이 정수에 %기호까지 표시
plt.show() 

plt.figure(figsize=(5,5)) 
plt.pie(result, labels = fruit, autopct='%.1f%%') #비율값이 소수점 첫째 자리와 %기호까지 표시(0.2,0.3)
plt.show()

# %% [markdown]
# # 히스토그램

# %%
math = [76, 82, 84, 83, 90, 86, 85, 92, 72, 71, 100, 87, 81, 76,
        94, 78, 81, 60, 79, 69, 74, 87, 82, 68, 79] 
plt.hist(math)
# Out:
# (array([1., 0., 3., 2., 5., 5., 5., 1., 2., 1.]),
#  array([ 60.,  64.,  68.,  72.,  76.,  80.,  84.,  88.,  92.,  96., 100.]),
#  <BarContainer object of 10 artists>)

# %%
# bins : 계급 수 조정
plt.figure(figsize=(10,6)) 
plt.subplot(1,2,1)
plt.hist(math)
plt.subplot(1,2,2)
plt.hist(math, bins=8)
plt.show()

# %%
# color : 색깔 조정
plt.figure(figsize=(10,6)) 
plt.subplot(1,2,1)
plt.hist(math)
plt.subplot(1,2,2)
plt.hist(math, color="pink")
# Out:
# (array([1., 0., 3., 2., 5., 5., 5., 1., 2., 1.]),
#  array([ 60.,  64.,  68.,  72.,  76.,  80.,  84.,  88.,  92.,  96., 100.]),
#  <BarContainer object of 10 artists>)

# %%
# 여러 옵션 사용
plt.hist(math, bins= 7, color="red") 
plt.xlabel('test score') 
plt.ylabel('frequency') 
plt.title('hist : math test') 
plt.grid() 
plt.show()

# %% [markdown]
# # 산점도

# %%
#데이터 생성
height = [165, 177, 160, 180, 185, 155, 172] # 키 데이터 
weight = [62, 67, 55, 74, 90, 43, 64] # 몸무게 데이터 
    
#그리기
plt.scatter(height, weight) 
plt.xlabel('Height(m)') 
plt.ylabel('Weight(Kg)') 
plt.title('Height & Weight') 
plt.grid(True)
plt.show()

# %%
# 데이터 생성하기
x = np.arange(0,5,1); x
y1 = x
y2 = x+1
y3 = x+2
y4 = x+3

plt.plot(x,y1,'>--r',x,y2,'s-g',x,y3,'d:b',x,y4,'-.Xc')
plt.legend(['data 1','data 2','data 3','data 4'], loc='best') # 주석
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('graph title')
plt.grid(True)
plt.show()

# %% [markdown]
# # 옵션

# %% [markdown]
# ## 문자열 옵션

# %%
plt.plot(x,y1,'>--r',x,y2,'s-g',x,y3,'d:b',x,y4,'-.Xc')
plt.text(0,6,"string 1")
plt.text(0,5,"string 2")
plt.text(3,1,"string 3")
plt.text(3,0,"string 4")
plt.show()

# %% [markdown]
# ## 색 조정하기

# %%
#c : 색깔 조정
plt.figure(figsize=(10,6)) 
plt.subplot(1,2,1)
plt.scatter(height, weight) 

plt.subplot(1,2,2)
plt.scatter(height, weight,c='r') # 컬러는 붉은색(red) 
plt.show()

#s : 마커 크기 조정
plt.figure(figsize=(10,6)) 
plt.subplot(1,2,1)
plt.scatter(height, weight) 

plt.subplot(1,2,2)
plt.scatter(height, weight, s=500) # 마커 크기는 500
plt.show()

#데이터마다 마커의 크기와 컬러 조정
size = 100 * np.arange(1,8) # 데이터별로 마커의 크기 지정 
size
colors = ['r', 'g', 'b', 'c', 'm', 'k', 'y'] # 데이터별로 마커의 컬러 지정 
plt.scatter(height, weight, s=size, c=colors) 
plt.show()

plt.scatter(height, weight, s=size, c='y') 
plt.show()

# %% [markdown]
# ## 위도와 경도 옵션

# %%
# zip을 이용해 리스트 여러개 다루기
names=['James','Robert','Lisa','Mary']
scores=[95,96,97,94]

for name, score in zip(names, scores):
    print(name, score)
# Out:
# James 95
# Robert 96
# Lisa 97
# Mary 94

# %%
# 도시
city = ['seoul', 'incheon', 'dajeon', 'daegu', 'ulsan', 'busan', 'gwangju'] 
# 위도(latitude)와 경도(longitude) 
lat  = [37.56, 37.45, 36.35, 35.87, 35.53, 35.18, 35.16]  
lon = [126.97, 126.70, 127.38, 128.60, 129.31, 129.07, 126.85] 
# 인구 밀도(명/km^2): 2017년 통계청 자료 
pop_den = [16154, 2751, 2839, 2790, 1099, 4454, 2995] 

size = np.array(pop_den) * 0.2 # 마커의 크기 지정
np.array(pop_den)
size
colors = ['r', 'g', 'b', 'c', 'm', 'k', 'y'] # 마커의 컬러 지정 

plt.scatter(lon, lat, s=size, c=colors, alpha=0.5) 
plt.xlabel('longitude') 
plt.ylabel('latitude') 
plt.title('population density by region(2017)') 

for x, y, name in zip(lon, lat, city):
    plt.text(x,y,name) # 위도 경도에 맞게 도시 이름 출력
plt.show()

# %% [markdown]
# # 그래프 저장

# %%
# 현재 설정된 그래프의 크기 확인방법
import matplotlib as mpl
mpl.rcParams['figure.figsize']
# Out:
# [6.0, 4.0]

# %%
# 현재 설정된 그래프의 dpi값 확인방법
mpl.rcParams['figure.dpi']
# Out:
# 72.0

# %%
fruit=['사과','바나나','딸기','오렌지','포도']
result=[7, 6, 3, 2, 2]
explode_value = (0.1, 0, 0, 0, 0)
plt.figure(figsize = (10, 10)) #그래프의 크기 지정
plt.pie(result, labels= fruit, autopct='%.1f%%', explode=explode_value) 

# 그래프를 이미지 파일로 저장. dpi는 200으로 설정 
plt.savefig('../data/saveFigTest.png', dpi = 30) 
plt.show()

# %%
plt.figure(figsize=(10,10)) #그래프의 크기 지정
# %matplotlib inline
plt.pie(result, labels= fruit, autopct='%.1f%%', explode=explode_value) 
plt.show()

# %%
plt.figure(figsize=(10,10)) # 그래프의 크기 지정
# %matplotlib inline
plt.pie(result, labels= fruit, autopct='%.1f%%', explode=explode_value) 
plt.show()

# %% [markdown]
# # 줄기와 잎 그림

# %%
#데이터 생성
math = [76,82,84,83,90,86,85,92,72,71,100,87,81,76,94,78,81,60,79,69,74,87,82,68,79] 
df_math = pd.DataFrame(math, columns = ['Student'])

# %%
import seaborn as sns
sns.color_palette('rocket')
sns.boxplot(math)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# # 박스플롯

# %%
plt.boxplot(math)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c5fd3ac940>,
#   <matplotlib.lines.Line2D at 0x1c5fd3accd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c5fd3b80a0>,
#   <matplotlib.lines.Line2D at 0x1c5fd3b8430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c5fd3ac5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c5fd3b87c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c5fd3b8b50>],
#  'means': []}
